# %%
import requests

# %%
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
standings_url = "https://fbref.com/en/comps/24/Serie-A-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a') # select uses css selectors (more flexible) find all only find tags
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/abdce579/Palmeiras-Stats',
#  '/en/squads/d5ae3703/Gremio-Stats',
#  '/en/squads/422bb734/Atletico-Mineiro-Stats',
#  '/en/squads/639950ae/Flamengo-Stats',
#  '/en/squads/d9fdd9d9/Botafogo-RJ-Stats',
#  '/en/squads/f98930d1/Bragantino-Stats',
#  '/en/squads/84d9701c/Fluminense-Stats',
#  '/en/squads/2091c619/Athletico-Paranaense-Stats',
#  '/en/squads/6f7e1f03/Internacional-Stats',
#  '/en/squads/a9d0ab0e/Fortaleza-Stats',
#  '/en/squads/5f232eb1/Sao-Paulo-Stats',
#  '/en/squads/f0e6fb14/Cuiaba-Stats',
#  '/en/squads/bf4acd28/Corinthians-Stats',
#  '/en/squads/03ff5eeb/Cruzeiro-Stats',
#  '/en/squads/83f55dbe/Vasco-da-Gama-Stats',
#  '/en/squads/157b7fee/Bahia-Stats',
#  '/en/squads/712c528f/Santos-Stats',
#  '/en/squads/78c617cc/Goias-Stats',
#  '/en/squads/d680d257/Coritiba-Stats',
#  '/en/squads/1f68d780/America-MG-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/abdce579/Palmeiras-Stats',
#  'https://fbref.com/en/squads/d5ae3703/Gremio-Stats',
#  'https://fbref.com/en/squads/422bb734/Atletico-Mineiro-Stats',
#  'https://fbref.com/en/squads/639950ae/Flamengo-Stats',
#  'https://fbref.com/en/squads/d9fdd9d9/Botafogo-RJ-Stats',
#  'https://fbref.com/en/squads/f98930d1/Bragantino-Stats',
#  'https://fbref.com/en/squads/84d9701c/Fluminense-Stats',
#  'https://fbref.com/en/squads/2091c619/Athletico-Paranaense-Stats',
#  'https://fbref.com/en/squads/6f7e1f03/Internacional-Stats',
#  'https://fbref.com/en/squads/a9d0ab0e/Fortaleza-Stats',
#  'https://fbref.com/en/squads/5f232eb1/Sao-Paulo-Stats',
#  'https://fbref.com/en/squads/f0e6fb14/Cuiaba-Stats',
#  'https://fbref.com/en/squads/bf4acd28/Corinthians-Stats',
#  'https://fbref.com/en/squads/03ff5eeb/Cruzeiro-Stats',
#  'https://fbref.com/en/squads/83f55dbe/Vasco-da-Gama-Stats',
#  'https://fbref.com/en/squads/157b7fee/Bahia-Stats',
# ...

# %%
data = requests.get(team_urls[0])

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures ")[0]

# %%
matches.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result GF GA  \
# 0  2023-04-05  20:30  Libertadores  Group stage  Wed  Away      L  1  3
# 1  2023-04-15  16:00       Série A  Matchweek 1  Sat  Home      W  2  1
# 2  2023-04-20  21:00  Libertadores  Group stage  Thu  Home      W  2  1
# 3  2023-04-23  16:00       Série A  Matchweek 2  Sun  Away      D  2  2
# 4  2023-04-29  18:30       Série A  Matchweek 3  Sat  Home      W  2  1
#
#            Opponent   xG  xGA  Poss  Attendance        Captain Formation  \
# 0        bo Bolívar  0.8  1.8    45         NaN    Luan Garcia     4-3-3
# 1            Cuiabá  3.0  1.0    52     35835.0  Gustavo Gómez   4-2-3-1
# 2  py Cerro Porteño  2.3  1.8    51         NaN  Gustavo Gómez   4-2-3-1
# 3     Vasco da Gama  0.7  1.4    64     59867.0  Gustavo Gómez   4-2-3-1
# 4       Corinthians  1.4  0.5    54     41457.0  Gustavo Gómez   4-2-3-1
#
#                           Referee  Match Report Notes
# ...

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
<a href="/en/squads/abdce579/2023/matchlogs/all_comps/shooting/Palmeiras-Match-Logs-All-Competitions">Shooting</a>

# %%
links
# Out:
# ['/en/squads/abdce579/2023/matchlogs/all_comps/shooting/Palmeiras-Match-Logs-All-Competitions',
#  '/en/squads/abdce579/2023/matchlogs/all_comps/shooting/Palmeiras-Match-Logs-All-Competitions',
#  '/en/squads/abdce579/2023/matchlogs/all_comps/shooting/Palmeiras-Match-Logs-All-Competitions',
#  '/en/squads/abdce579/2023/matchlogs/all_comps/shooting/Palmeiras-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Palmeiras                                                            \
#            Date   Time          Comp        Round  Day Venue Result GF GA
# 0    2023-04-05  20:30  Libertadores  Group stage  Wed  Away      L  1  3
# 1    2023-04-15  16:00       Série A  Matchweek 1  Sat  Home      W  2  1
# 2    2023-04-20  21:00  Libertadores  Group stage  Thu  Home      W  2  1
# 3    2023-04-23  16:00       Série A  Matchweek 2  Sun  Away      D  2  2
# 4    2023-04-29  18:30       Série A  Matchweek 3  Sat  Home      W  2  1
#
#                      ... Standard             Expected                    \
#            Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh G-xG
# 0        bo Bolívar  ...     19.5  0  0     0      0.8  0.8    0.09  0.2
# 1            Cuiabá  ...     16.3  0  0     0      3.0  3.0    0.18 -1.0
# 2  py Cerro Porteño  ...     15.3  1  0     0      2.3  2.3    0.14 -0.3
# 3     Vasco da Gama  ...     21.7  2  0     0      0.7  0.7    0.05  1.3
# ...

# %%
shooting.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Gls', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK',
#        'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG',
#        'Match Report'],
#       dtype='object')

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date") #selecting the columns not duplicated | merging over date column

# %%
team_data.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result GF GA  \
# 0  2023-04-05  20:30  Libertadores  Group stage  Wed  Away      L  1  3
# 1  2023-04-15  16:00       Série A  Matchweek 1  Sat  Home      W  2  1
# 2  2023-04-20  21:00  Libertadores  Group stage  Thu  Home      W  2  1
# 3  2023-04-23  16:00       Série A  Matchweek 2  Sun  Away      D  2  2
# 4  2023-04-29  18:30       Série A  Matchweek 3  Sat  Home      W  2  1
#
#            Opponent  ...  Formation                         Referee  \
# 0        bo Bolívar  ...      4-3-3                  Alexis Herrera
# 1            Cuiabá  ...    4-2-3-1  Paulo Cesar Zanovelli da Silva
# 2  py Cerro Porteño  ...    4-2-3-1              Fernando Rapallini
# 3     Vasco da Gama  ...    4-2-3-1            Rafael Rodrigo Klein
# 4       Corinthians  ...    4-2-3-1                  Wilton Sampaio
#
#    Match Report  Notes  Sh SoT  Dist FK PK  PKatt
# 0  Match Report    NaN   9   3  19.5  0  0      0
# ...

# %%
team_data.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt'],
#       dtype='object')

# %%
shooting.shape
# Out:
# (51, 26)

# %%
matches.shape
# Out:
# (50, 19)

# %%
team_data.shape
# Out:
# (50, 25)

# %%
years = list(range(2023, 2019, -1)) # tables of data can have different formats over the years | 2016 does not have FK data, i.e, what gives an error

# %%
years
# Out:
# [2023, 2022, 2021, 2020]

# %%
all_matches = []

# %%
# 6min - 4 years | 2020-2023
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]

    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"


    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures ")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        #team_data = team_data[team_data["Comp"] == "Premier League"]

        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(2) # slowing down the velocity of the scrapping to avoid problem in the website or blocking

# %%
shooting.tail()
# Out:
#           Date   Time     Comp         Round  Day Venue Result   GF   GA  \
# 40  2016-11-17  21:00  Série A  Matchweek 35  Thu  Away      D  1.0  1.0
# 41  2016-11-20  17:00  Série A  Matchweek 36  Sun  Home      W  1.0  0.0
# 42  2016-11-27  17:00  Série A  Matchweek 37  Sun  Home      W  1.0  0.0
# 43  2016-12-11  16:00  Série A  Matchweek 38  Sun  Away      W  2.0  1.0
# 44         NaN    NaN      NaN           NaN  NaN   NaN     --  NaN  NaN
#
#             Opponent  Gls   Sh  SoT  SoT%  G/Sh  G/SoT  Dist  PK  PKatt  \
# 40  Atlético Mineiro    1   12    4  33.3  0.08   0.25   NaN   0      0
# 41     Botafogo (RJ)    1   16    5  31.3  0.06   0.20   NaN   0      0
# 42       Chapecoense    1   21    3  14.3  0.05   0.33   NaN   0      0
# 43           Vitória    2   10    5  50.0  0.20   0.40   NaN   0      0
# 44               NaN   74  528  199  37.7  0.13   0.35   NaN   5      6
#
#     Match Report
# 40  Match Report
# 41  Match Report
# 42  Match Report
# 43  Match Report
# ...

# %%
len(all_matches)
# Out:
# 80

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time          comp         round  day venue result gf ga  \
# 0   2023-04-05  20:30  Libertadores   Group stage  Wed  Away      L  1  3
# 1   2023-04-15  16:00       Série A   Matchweek 1  Sat  Home      W  2  1
# 2   2023-04-20  21:00  Libertadores   Group stage  Thu  Home      W  2  1
# 3   2023-04-23  16:00       Série A   Matchweek 2  Sun  Away      D  2  2
# 4   2023-04-29  18:30       Série A   Matchweek 3  Sat  Home      W  2  1
# ..         ...    ...           ...           ...  ...   ...    ... .. ..
# 33  2021-02-05  20:00       Série A  Matchweek 34  Fri  Home      L  0  1
# 34  2021-02-08  20:00       Série A  Matchweek 35  Mon  Home      L  2  5
# 35  2021-02-13  17:00       Série A  Matchweek 36  Sat  Away      L  0  2
# 36  2021-02-22  20:00       Série A  Matchweek 37  Mon  Home      W  1  0
# 37  2021-02-25  21:30       Série A  Matchweek 38  Thu  Away      L  1  2
#
#             opponent  ...  match report  notes  sh  sot  dist   fk pk pkatt  \
# ...

# %%
match_df.to_csv("matches.csv", encoding='utf-8-sig', index=False)
